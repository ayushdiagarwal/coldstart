# %% [markdown]
# Keep users with ≥20 ratings
# Keep top 10k most-rated movies
# Convert ratings ≥4 → interaction = 1

# %%
import pandas as pd
import math

# %%
df_movies = pd.read_csv("ml-25m/movies.csv", index_col="movieId")
df_ratings = pd.read_csv("ml-25m/ratings.csv")
print(df_movies.shape)
print(df_ratings.shape)
# Out:
# (62423, 2)
# (25000095, 4)

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
counts = {}
for row in df_ratings.itertuples():
    id = row.movieId
    if id in counts:
        counts[id]+=1
    else:
        counts[id] = 1

# %%
freq = []
for id in counts:
    freq.append((id,counts[id]))

# %%
sorted_data = sorted(freq, key=lambda x: x[1], reverse=True)
print(f"Total no of rated movies: {len(sorted_data)}")
# Out:
# Total no of rated movies: 59047

# %%
# For now, we're only going to be working with the top 5000 movies, reducing our database
movies = sorted_data[:5000]
print(movies)
# Out:
# [(356, 81491), (318, 81482), (296, 79672), (593, 74127), (2571, 72674), (260, 68717), (480, 64144), (527, 60411), (110, 59184), (2959, 58773), (589, 57379), (1196, 57361), (1, 57309), (4993, 55736), (50, 55366), (1210, 54917), (1198, 54675), (2858, 53689), (858, 52498), (5952, 51138), (7153, 50797), (47, 50596), (457, 49638), (1270, 49595), (780, 48902), (150, 48377), (608, 47823), (32, 47054), (2028, 46783), (2762, 46713), (3578, 44656), (592, 44110), (588, 43373), (364, 42745), (4306, 42303), (380, 41673), (590, 41615), (58559, 41519), (377, 41302), (4226, 41195), (1580, 40308), (1704, 38947), (79132, 38895), (1240, 38612), (1291, 37908), (1197, 37863), (1136, 37723), (1721, 37712), (1265, 37616), (344, 37453), (6539, 37227), (648, 37035), (1036, 36716), (541, 36702), (1214, 36357), (1193, 36058), (595, 35723), (6377, 34712), (1089, 34634), (367, 34621), (1097, 34602), (4886, 34572), (4973, 34320), (597, 34234), (500, 34194), (1221, 34188), (6874, 33827), (1682, 33731), (165, 33731), (293, 33680), (7361, 33225), (1527, 33153), (1213, 32663), (3793, 32584), (2716, 32118), (733, 31979), (231, 31843), (2628, 31837), (4963, 31775), (4995, 31760), (1200, 31684), (34, 31456), (2329, 31157), (153, 31101), (736, 31040), (316, 30910), (33794, 30684), (8961, 30562), (3147, 30482), (5445, 30195), (5349, 30010), (2997, 29943), (1258, 29931), (1206, 29856), (586, 29540), (111, 29133), (5418, 28934), (924, 28820), (778, 28702), (587, 28516), (7438, 28502), (10, 28265), (539, 28137), (1073, 28079), (5989, 27935), (3996, 27905), (1732, 27826), (1961, 27813), (349, 27766), (1617, 27749), (253, 27577), (208, 27377), (60069, 27374), (4878, 27181), (2918, 27099), (912, 26890), (750, 26714), (357, 26709), (3114, 26536), (1208, 26370), (39, 26230), (4896, 26033), (44191, 25990), (1222, 25946), (59315, 25671), (48516, 25343), (1923, 25144), (68954, 25127), (4011, 25101), (4022, 25024), (1246, 24954), (2683, 24951), (2706, 24867), (292, 24760), (919, 24658), (329, 24615), (6, 24588), (72998, 24548), (2115, 24306), (2, 24228), (1387, 24188), (454, 24161), (1968, 24077), (2396, 24063), (223, 24050), (2324, 23976), (2291, 23807), (4027, 23259), (288, 23259), (1517, 23254), (1784, 23145), (434, 23089), (68157, 23077), (1307, 23074), (6365, 23064), (185, 23018), (2011, 22990), (1393, 22960), (2502, 22957), (48780, 22943), (5618, 22719), (1259, 22694), (1917, 22671), (109487, 22634), (8368, 22561), (1080, 22484), (2355, 22471), (2916, 22428), (161, 22340), (21, 22277), (32587, 22271), (1610, 22165), (1219, 22146), (339, 22111), (3949, 22066), (5816, 22030), (551, 21940), (2987, 21899), (1653, 21890), (2012, 21881), (1584, 21638), (19, 21552), (1225, 21085), (5378, 21079), (2174, 20847), (141, 20757), (8636, 20725), (99114, 20687), (95, 20642), (2791, 20475), (54286, 20474), (1220, 20460), (49272, 20455), (1101, 20453), (2797, 20407), (6711, 20288), (8360, 20198), (904, 20162), (1573, 20129), (8665, 20091), (25, 20070), (3948, 20058), (6333, 19963), (91529, 19912), (508, 19902), (6016, 19894), (3897, 19887), (48394, 19868), (17, 19729), (1079, 19715), (8874, 19558), (2710, 19486), (36, 19388), (2542, 19260), (1356, 19202), (104, 19190), (50872, 19157), (788, 19138), (2617, 19103), (923, 19091), (63082, 19073), (46578, 19048), (300, 18997), (2000, 18949), (2692, 18891), (74458, 18886), (40815, 18848), (1485, 18777), (51662, 18769), (3751, 18762), (1247, 18724), (33493, 18703), (1625, 18647), (55820, 18474), (16, 18404), (3623, 18337), (56367, 18306), (62, 18242), (5218, 18215), (1201, 18162), (3408, 18105), (442, 18088), (6934, 18074), (474, 17996), (70286, 17970), (594, 17940), (3977, 17923), (440, 17918), (410, 17836), (1391, 17814), (2700, 17806), (89745, 17572), (1127, 17568), (7147, 17528), (8644, 17321), (1676, 17245), (337, 17234), (3052, 17152), (5995, 17070), (11, 17042), (4034, 17023), (3481, 17019), (1252, 16929), (1954, 16918), (908, 16850), (1090, 16796), (3527, 16762), (1407, 16657), (1203, 16569), (1288, 16558), (3994, 16557), (1370, 16548), ...

# %%
i = 0
for movie in movies:
    if i > 10:
        break
    else:
        print(df_movies.loc[movie[0], "title"])
    i+=1
# Out:
# Forrest Gump (1994)
# Shawshank Redemption, The (1994)
# Pulp Fiction (1994)
# Silence of the Lambs, The (1991)
# Matrix, The (1999)
# Star Wars: Episode IV - A New Hope (1977)
# Jurassic Park (1993)
# Schindler's List (1993)
# Braveheart (1995)
# Fight Club (1999)
# Terminator 2: Judgment Day (1991)

# %% [markdown]
# let's make a new sampled down csv which only contains entries from our top 5k movies

# %%
top_k = df_ratings[df_ratings["movieId"].isin([x[0] for x in movies])]

top_k.to_csv("top5kratings.csv", index=False)

# %%
# now top_k contains all the ratings related to the first top5k movies
top_k.shape
# Out:
# (23062613, 4)

# %% [markdown]
# ### Converting rationgs into interactions
#
# | rating | interaction |
# | ------ | ----------- |
# | ≥ 4    | 1           |
# | < 4   | ignore      |

# %%
top_k = top_k[top_k["rating"] >= 4].copy()
top_k["rating"] = 1

# %% [markdown]
# Removing all users who have rated less than 8 films

# %%
MIN_LIKES = 8 
user_like_counts = top_k.groupby("userId").size()

valid_users = user_like_counts[user_like_counts >= MIN_LIKES].index
top_k = top_k[top_k["userId"].isin(valid_users)]

top_k.to_csv("top5kratings.csv", index=False)

print("Remaining users:", top_k["userId"].nunique())
# Out:
# Remaining users: 157188

# %% [markdown]
# for each user, we need to make pairs of all the movies he likes.
# If there are n users, and each users likes m movies. Then we are left with $ n * (m) * (m-1) * 0.5$ pairs
#
# We can compress this pairs by building a matrix of movies in which
#
# $ mat[i][j] = count $
#
# shows how many times that pair occurs.

# %%
cooccur = {}
# if i < j 
# we don't care about the users at this point, we just want co-occurence of movies together.

# for a particular user, make list of all likes pairs

# for index, row in top_k.iterrows():

# %%
rows, cols = top_k.shape

top_k = top_k.reset_index(drop=True)
top_k.loc[2]
# Out:
# userId                1
# movieId             665
# rating                1
# timestamp    1147878820
# Name: 2, dtype: int64

# %%
# This creates a Series where the index is userId and the value is a list of movieIds
user_movie_lists = top_k.groupby("userId")["movieId"].apply(list)
# Out:
# pandas.core.series.Series

# %%
cooccur = {}

for user_id, movies in user_movie_lists.items():
    movies = list(set(movies))
    for i in range(len(movies)):
        for j in range(i+1, len(movies)):

            mini = min(movies[i], movies[j])
            maxi = max(movies[i], movies[j])

            if mini not in cooccur:
                cooccur[mini] = {}

            if maxi not in cooccur[mini]:
                cooccur[mini][maxi] = 0

            cooccur[mini][maxi] += 1

# %%
sum = 0
for i in cooccur:
    sum += len(cooccur[i])

print(sum)
# Out:
# 11897138

# %% [markdown]
# Using Pointwise Mutual Information to remove popularity bias

# %%
movie_likes = {}
for user, movies in user_movie_lists.items():
    for m in set(movies):          # deduplicated per user
        movie_likes[m] = movie_likes.get(m, 0) + 1

# %%
TOTAL_USERS = len(user_movie_lists)
TOTAL_USERS
# Out:
# 157188

# %%
pmi_graph = {}

for i in cooccur:
    pmi_graph[i] = {}
    for j, cij in cooccur[i].items():
        val = math.log((cij * TOTAL_USERS) /
                       (movie_likes[i] * movie_likes[j]))

        if val > 0:                     # keep only meaningful associations
            pmi_graph[i][j] = val
